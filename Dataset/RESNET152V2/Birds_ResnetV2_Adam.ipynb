# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, Input
from keras.callbacks import TensorBoard, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
import os
import numpy as np
from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
import math
from tensorflow.keras import mixed_precision
# %matplotlib inline

# %%
train_data_dir = r'C:\Users\johns\Desktop\TFG\Dataset\train'
validation_data_dir = r'C:\Users\johns\Desktop\TFG\Dataset\valid'

# %%
width_shape = 224
height_shape = 224
epochs = 100
num_classes = len(os.listdir(train_data_dir))
batch_size = 32
image_shape = (224,224,3)

# %%
from keras.applications.resnet_v2 import preprocess_input

# Data generators with data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest', # Últimos cambios añadidos de una consulta
    )

valid_datagen = ImageDataGenerator(rescale=1./255) # Sin aumentos de datos para la validación

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(width_shape, height_shape),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True) # Activa y Desactiva el mezclado de los datos de prueba

validation_generator = valid_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(width_shape, height_shape),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True) # Activa y Desactiva el mezclado de los datos de prueba

for _ in range(3):
    img, label = next(train_generator)
    plt.imshow(img[0])
    plt.show()
# Out:
# Found 12396 images belonging to 24 classes.
# Found 2564 images belonging to 24 classes.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.applications.resnet_v2 import ResNet152V2
from sklearn.utils.class_weight import compute_class_weight

# Fit the model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Load pre-trained ResNet152V2 model
resnet_model=tf.keras.applications.ResNet152V2(input_shape=image_shape,
                                            include_top=False,
                                            weights='imagenet')

resnet_model.trainable = False

custom_resnet_model = keras.Sequential([
  resnet_model,
  layers.Flatten(),
  layers.Dense(units=1024, activation='relu'),
  layers.BatchNormalization(),
  layers.Dropout(0.5),
  layers.Dense(units=num_classes, activation="softmax"),
])

custom_resnet_model.summary()

# Compile the model
custom_resnet_model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy']
)

# Calculate class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)

# Convert class weights to dictionary
class_weights_dict = dict(zip(np.unique(train_generator.classes), class_weights))

checkpoint = ModelCheckpoint(r'C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\best_resnetv2_NAmodel.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# early_stop = EarlyStopping(monitor='val_loss', patience=10)

custom_resnet_model_history = custom_resnet_model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    verbose=1,
    callbacks=[checkpoint, early_stopping, reduce_lr],
    class_weight=class_weights_dict
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152v2 (Functional)    (None, 7, 7, 2048)        58331648
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 1024)              102761472
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 24)                24600
#
# =================================================================
# Total params: 161,121,816
# Trainable params: 102,788,120
# Non-trainable params: 58,333,696
# _________________________________________________________________
# Epoch 1/100
# 388/388 [==============================] - ETA: 0s - loss: 1.4281 - accuracy: 0.6179
# Epoch 1: val_accuracy improved from -inf to 0.74610, saving model to C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 153s 361ms/step - loss: 1.4281 - accuracy: 0.6179 - val_loss: 0.9291 - val_accuracy: 0.7461 - lr: 0.0010
# Epoch 2/100
# 388/388 [==============================] - ETA: 0s - loss: 0.8851 - accuracy: 0.7188
# Epoch 2: val_accuracy improved from 0.74610 to 0.77613, saving model to C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 138s 355ms/step - loss: 0.8851 - accuracy: 0.7188 - val_loss: 0.7820 - val_accuracy: 0.7761 - lr: 0.0010
# Epoch 3/100
# 388/388 [==============================] - ETA: 0s - loss: 0.7330 - accuracy: 0.7592
# Epoch 3: val_accuracy did not improve from 0.77613
# 388/388 [==============================] - 131s 335ms/step - loss: 0.7330 - accuracy: 0.7592 - val_loss: 0.8354 - val_accuracy: 0.7598 - lr: 0.0010
# Epoch 4/100
# 388/388 [==============================] - ETA: 0s - loss: 0.6861 - accuracy: 0.7768
# Epoch 4: val_accuracy did not improve from 0.77613
# 388/388 [==============================] - 130s 335ms/step - loss: 0.6861 - accuracy: 0.7768 - val_loss: 0.7929 - val_accuracy: 0.7683 - lr: 0.0010
# Epoch 5/100
# 388/388 [==============================] - ETA: 0s - loss: 0.6010 - accuracy: 0.7975
# Epoch 5: val_accuracy improved from 0.77613 to 0.79485, saving model to C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 136s 351ms/step - loss: 0.6010 - accuracy: 0.7975 - val_loss: 0.7191 - val_accuracy: 0.7949 - lr: 0.0010
# Epoch 6/100
# 388/388 [==============================] - ETA: 0s - loss: 0.5740 - accuracy: 0.8074
# Epoch 6: val_accuracy did not improve from 0.79485
# 388/388 [==============================] - 131s 337ms/step - loss: 0.5740 - accuracy: 0.8074 - val_loss: 0.7907 - val_accuracy: 0.7722 - lr: 0.0010
# Epoch 7/100
# 388/388 [==============================] - ETA: 0s - loss: 0.5301 - accuracy: 0.8167
# Epoch 7: val_accuracy did not improve from 0.79485
# 388/388 [==============================] - 133s 343ms/step - loss: 0.5301 - accuracy: 0.8167 - val_loss: 0.7518 - val_accuracy: 0.7878 - lr: 0.0010
# Epoch 8/100
# 388/388 [==============================] - ETA: 0s - loss: 0.5191 - accuracy: 0.8279
# Epoch 8: val_accuracy improved from 0.79485 to 0.80031, saving model to C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 137s 352ms/step - loss: 0.5191 - accuracy: 0.8279 - val_loss: 0.7405 - val_accuracy: 0.8003 - lr: 0.0010
# Epoch 9/100
# 388/388 [==============================] - ETA: 0s - loss: 0.4860 - accuracy: 0.8269
# Epoch 9: val_accuracy did not improve from 0.80031
# 388/388 [==============================] - 132s 339ms/step - loss: 0.4860 - accuracy: 0.8269 - val_loss: 0.6998 - val_accuracy: 0.7941 - lr: 0.0010
# Epoch 10/100
# 388/388 [==============================] - ETA: 0s - loss: 0.4968 - accuracy: 0.8331
# Epoch 10: val_accuracy improved from 0.80031 to 0.80148, saving model to C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 136s 351ms/step - loss: 0.4968 - accuracy: 0.8331 - val_loss: 0.7053 - val_accuracy: 0.8015 - lr: 0.0010
# Epoch 11/100
# 388/388 [==============================] - ETA: 0s - loss: 0.4598 - accuracy: 0.8328
# Epoch 11: val_accuracy improved from 0.80148 to 0.80616, saving model to C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 136s 350ms/step - loss: 0.4598 - accuracy: 0.8328 - val_loss: 0.6853 - val_accuracy: 0.8062 - lr: 0.0010
# Epoch 12/100
# 388/388 [==============================] - ETA: 0s - loss: 0.4324 - accuracy: 0.8466
# Epoch 12: val_accuracy did not improve from 0.80616
# 388/388 [==============================] - 130s 335ms/step - loss: 0.4324 - accuracy: 0.8466 - val_loss: 0.7369 - val_accuracy: 0.7933 - lr: 0.0010
# Epoch 13/100
# 388/388 [==============================] - ETA: 0s - loss: 0.4162 - accuracy: 0.8505
# Epoch 13: val_accuracy did not improve from 0.80616
# 388/388 [==============================] - 132s 340ms/step - loss: 0.4162 - accuracy: 0.8505 - val_loss: 0.7351 - val_accuracy: 0.8034 - lr: 0.0010
# Epoch 14/100
# 388/388 [==============================] - ETA: 0s - loss: 0.4007 - accuracy: 0.8558
# Epoch 14: val_accuracy improved from 0.80616 to 0.81045, saving model to C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 138s 354ms/step - loss: 0.4007 - accuracy: 0.8558 - val_loss: 0.7622 - val_accuracy: 0.8105 - lr: 0.0010
# Epoch 15/100
# 388/388 [==============================] - ETA: 0s - loss: 0.4110 - accuracy: 0.8633
# Epoch 15: val_accuracy did not improve from 0.81045
# 388/388 [==============================] - 131s 337ms/step - loss: 0.4110 - accuracy: 0.8633 - val_loss: 0.7292 - val_accuracy: 0.8066 - lr: 0.0010
# Epoch 16/100
# 388/388 [==============================] - ETA: 0s - loss: 0.3863 - accuracy: 0.8635
# Epoch 16: val_accuracy improved from 0.81045 to 0.81162, saving model to C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 136s 350ms/step - loss: 0.3863 - accuracy: 0.8635 - val_loss: 0.6904 - val_accuracy: 0.8116 - lr: 0.0010
# Epoch 17/100
# 388/388 [==============================] - ETA: 0s - loss: 0.3197 - accuracy: 0.8831
# Epoch 17: val_accuracy improved from 0.81162 to 0.82917, saving model to C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 137s 351ms/step - loss: 0.3197 - accuracy: 0.8831 - val_loss: 0.6394 - val_accuracy: 0.8292 - lr: 2.0000e-04
# Epoch 18/100
# 388/388 [==============================] - ETA: 0s - loss: 0.2760 - accuracy: 0.8960
# Epoch 18: val_accuracy did not improve from 0.82917
# 388/388 [==============================] - 131s 336ms/step - loss: 0.2760 - accuracy: 0.8960 - val_loss: 0.6442 - val_accuracy: 0.8253 - lr: 2.0000e-04
# Epoch 19/100
# 388/388 [==============================] - ETA: 0s - loss: 0.2622 - accuracy: 0.9018
# Epoch 19: val_accuracy did not improve from 0.82917
# 388/388 [==============================] - 133s 343ms/step - loss: 0.2622 - accuracy: 0.9018 - val_loss: 0.6491 - val_accuracy: 0.8268 - lr: 2.0000e-04
# Epoch 20/100
# 388/388 [==============================] - ETA: 0s - loss: 0.2611 - accuracy: 0.9053
# Epoch 20: val_accuracy did not improve from 0.82917
# 388/388 [==============================] - 132s 339ms/step - loss: 0.2611 - accuracy: 0.9053 - val_loss: 0.6526 - val_accuracy: 0.8268 - lr: 2.0000e-04
# Epoch 21/100
# 388/388 [==============================] - ETA: 0s - loss: 0.2470 - accuracy: 0.9062
# Epoch 21: val_accuracy improved from 0.82917 to 0.83424, saving model to C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 139s 358ms/step - loss: 0.2470 - accuracy: 0.9062 - val_loss: 0.6387 - val_accuracy: 0.8342 - lr: 2.0000e-04
# Epoch 22/100
# 388/388 [==============================] - ETA: 0s - loss: 0.2308 - accuracy: 0.9117
# Epoch 22: val_accuracy did not improve from 0.83424
# 388/388 [==============================] - 131s 336ms/step - loss: 0.2308 - accuracy: 0.9117 - val_loss: 0.6493 - val_accuracy: 0.8339 - lr: 2.0000e-04
# Epoch 23/100
# 388/388 [==============================] - ETA: 0s - loss: 0.2177 - accuracy: 0.9163
# Epoch 23: val_accuracy improved from 0.83424 to 0.83775, saving model to C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 138s 354ms/step - loss: 0.2177 - accuracy: 0.9163 - val_loss: 0.6329 - val_accuracy: 0.8378 - lr: 2.0000e-04
# Epoch 24/100
# 388/388 [==============================] - ETA: 0s - loss: 0.2159 - accuracy: 0.9161
# Epoch 24: val_accuracy did not improve from 0.83775
# 388/388 [==============================] - 131s 336ms/step - loss: 0.2159 - accuracy: 0.9161 - val_loss: 0.6353 - val_accuracy: 0.8354 - lr: 2.0000e-04
# Epoch 25/100
# 388/388 [==============================] - ETA: 0s - loss: 0.2045 - accuracy: 0.9202
# Epoch 25: val_accuracy did not improve from 0.83775
# 388/388 [==============================] - 133s 343ms/step - loss: 0.2045 - accuracy: 0.9202 - val_loss: 0.6334 - val_accuracy: 0.8303 - lr: 2.0000e-04
# Epoch 26/100
# 388/388 [==============================] - ETA: 0s - loss: 0.2008 - accuracy: 0.9225
# Epoch 26: val_accuracy did not improve from 0.83775
# 388/388 [==============================] - 133s 342ms/step - loss: 0.2008 - accuracy: 0.9225 - val_loss: 0.6659 - val_accuracy: 0.8331 - lr: 2.0000e-04
# Epoch 27/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9289
# Epoch 27: val_accuracy did not improve from 0.83775
# 388/388 [==============================] - 132s 340ms/step - loss: 0.1878 - accuracy: 0.9289 - val_loss: 0.6969 - val_accuracy: 0.8307 - lr: 2.0000e-04
# Epoch 28/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1745 - accuracy: 0.9318
# Epoch 28: val_accuracy did not improve from 0.83775
# 388/388 [==============================] - 131s 338ms/step - loss: 0.1745 - accuracy: 0.9318 - val_loss: 0.6745 - val_accuracy: 0.8253 - lr: 2.0000e-04
# Epoch 29/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1699 - accuracy: 0.9355
# Epoch 29: val_accuracy did not improve from 0.83775
# 388/388 [==============================] - 132s 339ms/step - loss: 0.1699 - accuracy: 0.9355 - val_loss: 0.6856 - val_accuracy: 0.8300 - lr: 4.0000e-05
# Epoch 30/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1681 - accuracy: 0.9332
# Epoch 30: val_accuracy did not improve from 0.83775
# 388/388 [==============================] - 131s 338ms/step - loss: 0.1681 - accuracy: 0.9332 - val_loss: 0.6594 - val_accuracy: 0.8296 - lr: 4.0000e-05
# Epoch 31/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1672 - accuracy: 0.9364
# Epoch 31: val_accuracy did not improve from 0.83775
# 388/388 [==============================] - 134s 344ms/step - loss: 0.1672 - accuracy: 0.9364 - val_loss: 0.6481 - val_accuracy: 0.8346 - lr: 4.0000e-05
# Epoch 32/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1632 - accuracy: 0.9349
# Epoch 32: val_accuracy did not improve from 0.83775
# 388/388 [==============================] - 133s 342ms/step - loss: 0.1632 - accuracy: 0.9349 - val_loss: 0.6566 - val_accuracy: 0.8358 - lr: 4.0000e-05
# Epoch 33/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1574 - accuracy: 0.9383
# Epoch 33: val_accuracy did not improve from 0.83775
# 388/388 [==============================] - 132s 341ms/step - loss: 0.1574 - accuracy: 0.9383 - val_loss: 0.6623 - val_accuracy: 0.8335 - lr: 4.0000e-05

# %%
custom_resnet_model.save(r'C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\custom_resnetv2_NAmodel.h5')

# %%
def plotTraining(hist, epochs, typeData):

    if typeData=="loss":
        plt.figure(1,figsize=(10,5))
        yc=hist.history['loss']
        xc=range(epochs)
        plt.ylabel('Loss', fontsize=24)
        plt.plot(xc,yc,'-r',label='Loss Training')
    if typeData=="accuracy":
        plt.figure(2,figsize=(10,5))
        yc=hist.history['accuracy']
        for i in range(0, len(yc)):
            yc[i]=100*yc[i]
        xc=range(epochs)
        plt.ylabel('Accuracy (%)', fontsize=24)
        plt.plot(xc,yc,'-r',label='Accuracy Training')
    if typeData=="val_loss":
        plt.figure(1,figsize=(10,5))
        yc=hist.history['val_loss']
        xc=range(epochs)
        plt.ylabel('Loss', fontsize=24)
        plt.plot(xc,yc,'-b',label='Loss Validate')
    if typeData=="val_accuracy":
        plt.figure(2,figsize=(10,5))
        yc=hist.history['val_accuracy']
        for i in range(0, len(yc)):
            yc[i]=100*yc[i]
        xc=range(epochs)
        plt.ylabel('Accuracy (%)', fontsize=24)
        plt.plot(xc,yc,'-b',label='Training Validate')


    plt.rc('xtick',labelsize=24)
    plt.rc('ytick',labelsize=24)
    plt.rc('legend', fontsize=18)
    plt.legend()
    plt.xlabel('Number of Epochs',fontsize=24)
    plt.grid(True)

# %%
num_epochs_done = len(custom_resnet_model_history.history['loss'])

plotTraining(custom_resnet_model_history,num_epochs_done,"loss")
plotTraining(custom_resnet_model_history,num_epochs_done,"accuracy")
plotTraining(custom_resnet_model_history,num_epochs_done,"val_loss")
plotTraining(custom_resnet_model_history,num_epochs_done,"val_accuracy")

# %%
from keras.applications.imagenet_utils import preprocess_input, decode_predictions
from tensorflow.keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array

# nombres de las clases
names = ['AGUJA COLINERA',
          'ALCA COMÚN',
          'AVEFRÍA EUROPEA',
          'AVIÓN ROQUERO',
          'AVOCETA COMÚN',
          'CHARRÁN PATINEGRO',
          'CHORLITO DORADO EUROPEO',
          'ESTORNINO PINTO',
          'FLAMENCO COMUN',
          'FOCHA COMUN',
          'GARCILLA VUEYERA OCCIDENTAL',
          'GAVIOTA PATIAMARILLA',
          'GAVIOTA PICOFINA',
          'GAVIOTA REIDORA',
          'GOLONDRINA COMUN',
          'GORRIÓN COMÚN',
          'GRAJILLA OCCIDENTAL',
          'JILGUERO EUROPEO',
          'MORITO COMÚN',
          'PALOMA TORCAZ',
          'PARDELA BALEAR',
          'PATO CUCHARÓN NORTEÑO',
          'SERÍN VERDECILLO',
          'VENCEJO COMÚN']

# cargar el 
modelt = load_model(r"C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\best_resnetv2_NAmodel.h5")

# ruta de la imagen
imaget_path = r'C:\Users\johns\Desktop\TFG\Dataset\test\SERÍN VERDECILLO\1365.jpg'

# cargar y redimensionar la imagen
imaget = load_img(imaget_path, target_size=(width_shape, height_shape))
imaget = img_to_array(imaget)
imaget = imaget.reshape((1,) + imaget.shape)

# preprocesar la imagen
xt = imaget / 255.0  # Normalizar la imagen

# hacer predicciones
preds = modelt.predict(xt)

# obtener la clase predicha
predicted_class = np.argmax(preds)
class_name = names[predicted_class]

print(class_name)

# mostrar la imagen
plt.imshow(cv2.cvtColor(imaget.reshape(width_shape, height_shape, 3).astype(np.uint8), cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# SERÍN VERDECILLO

# %%
from sklearn.metrics import confusion_matrix, classification_report
from keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, f1_score, roc_curve, precision_score, recall_score, accuracy_score, roc_auc_score
from keras.preprocessing.image import ImageDataGenerator
from sklearn import metrics
from mlxtend.plotting import plot_confusion_matrix
# %matplotlib inline

# Definir el generador de datos de prueba
test_data_dir = r'C:\Users\johns\Desktop\TFG\Dataset\test'

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(height_shape, width_shape),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=False
)

# Load the model
custom_Model= load_model(r'C:\Users\johns\Desktop\TFG\Dataset\RESNET152V2\custom_resnetv2_NAmodel.h5')

# Make predictions
predictions = custom_Model.predict_generator(generator=test_generator, steps=len(test_generator))
y_pred = np.argmax(predictions, axis=1)
y_real = test_generator.classes

# Map class names to class indices
class_indices = test_generator.class_indices
names = list(class_indices.keys())

# Generate confusion matrix
conf_matrix = confusion_matrix(y_real, y_pred)

# Plot confusion matrix
plt.figure(figsize=(15, 15))

plot_confusion_matrix(conf_mat=conf_matrix, figsize=(15, 15), class_names=names, show_normed=True)
plt.tight_layout()

# Print classification report
print(classification_report(y_real, y_pred, digits = 4))
# Out:
# Found 1873 images belonging to 24 classes.
# C:\Users\johns\AppData\Local\Temp\ipykernel_14280\3237459386.py:29: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = custom_Model.predict_generator(generator=test_generator, steps=len(test_generator))
#               precision    recall  f1-score   support
#
#            0     0.8682    0.8960    0.8819       125
#            1     0.9217    0.8833    0.9021       120
#            2     0.8525    0.8667    0.8595       120
#            3     0.8851    0.7333    0.8021       105
#            4     0.8462    0.9167    0.8800        60
#            5     0.8837    0.9157    0.8994        83
#            6     0.8769    0.9500    0.9120        60
#            7     0.8701    0.8701    0.8701        77
#            8     0.9796    0.9600    0.9697        50
#            9     0.8571    0.9429    0.8980        70
#           10     0.9487    0.9250    0.9367        80
#           11     0.8675    0.7579    0.8090        95
#           12     0.2222    0.3333    0.2667         6
#           13     0.7209    0.9118    0.8052        68
#           14     0.8382    0.8906    0.8636        64
#           15     0.8182    0.8308    0.8244        65
#           16     0.8026    0.8714    0.8356        70
#           17     0.7681    0.8281    0.7970        64
#           18     0.9449    0.8889    0.9160       135
#           19     0.8906    0.7600    0.8201       150
#           20     0.6250    1.0000    0.7692        10
#           21     0.9714    0.8870    0.9273       115
#           22     0.8767    0.9014    0.8889        71
#           23     0.3529    0.6000    0.4444        10
#
#     accuracy                         0.8644      1873
#    macro avg     0.8121    0.8467    0.8241      1873
# weighted avg     0.8718    0.8644    0.8657      1873

# %%
print(y_real)
# Out:
# [ 0  0  0 ... 23 23 23]

# %%
print(y_pred)
# Out:
# [ 9  0  0 ... 11 23  3]
