# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, Input
from keras.callbacks import TensorBoard, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
import os
import numpy as np
from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
import math
from tensorflow.keras import mixed_precision
# %matplotlib inline

# %%
train_data_dir = r'C:\Users\johns\Desktop\TFG\Dataset\train'
validation_data_dir = r'C:\Users\johns\Desktop\TFG\Dataset\valid'

# %%
width_shape = 224
height_shape = 224
epochs = 100
num_classes = len(os.listdir(train_data_dir))
batch_size = 32
image_shape = (224,224,3)

# %%
from keras.applications.resnet_v2 import preprocess_input

# Data generators with data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest', # Últimos cambios añadidos de una consulta
    )

valid_datagen = ImageDataGenerator(rescale=1./255) # Sin aumentos de datos para la validación

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(width_shape, height_shape),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True) # Activa y Desactiva el mezclado de los datos de prueba

validation_generator = valid_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(width_shape, height_shape),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True) # Activa y Desactiva el mezclado de los datos de prueba

for _ in range(3):
    img, label = next(train_generator)
    plt.imshow(img[0])
    plt.show()
# Out:
# Found 12396 images belonging to 24 classes.
# Found 2564 images belonging to 24 classes.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.applications.resnet_v2 import ResNet152V2
from sklearn.utils.class_weight import compute_class_weight

# Fit the model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Load pre-trained ResNet152V2 model
resnet_model=tf.keras.applications.ResNet152V2(input_shape=image_shape,
                                            include_top=False,
                                            weights='imagenet')

resnet_model.trainable = False

custom_resnet_model = keras.Sequential([
  resnet_model,
  layers.Flatten(),
  layers.Dense(units=1024, activation='relu'),
  layers.BatchNormalization(),
  layers.Dropout(0.2),
  layers.Dense(units=num_classes, activation="softmax"),
])

custom_resnet_model.summary()

# Compile the model
custom_resnet_model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy']
)

# Calculate class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)

# Convert class weights to dictionary
class_weights_dict = dict(zip(np.unique(train_generator.classes), class_weights))

checkpoint = ModelCheckpoint(r'C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

# early_stop = EarlyStopping(monitor='val_loss', patience=10)

custom_resnet_model_history = custom_resnet_model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    verbose=1,
    callbacks=[checkpoint, early_stopping, reduce_lr],
    class_weight=class_weights_dict
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152v2 (Functional)    (None, 7, 7, 2048)        58331648
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 1024)              102761472
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 24)                24600
#
# =================================================================
# Total params: 161,121,816
# Trainable params: 102,788,120
# Non-trainable params: 58,333,696
# _________________________________________________________________
# Epoch 1/100
# 388/388 [==============================] - ETA: 0s - loss: 1.3026 - accuracy: 0.6461
# Epoch 1: val_accuracy improved from -inf to 0.74454, saving model to C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 154s 365ms/step - loss: 1.3026 - accuracy: 0.6461 - val_loss: 0.9078 - val_accuracy: 0.7445 - lr: 0.0010
# Epoch 2/100
# 388/388 [==============================] - ETA: 0s - loss: 0.7700 - accuracy: 0.7570
# Epoch 2: val_accuracy improved from 0.74454 to 0.76911, saving model to C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 143s 367ms/step - loss: 0.7700 - accuracy: 0.7570 - val_loss: 0.8385 - val_accuracy: 0.7691 - lr: 0.0010
# Epoch 3/100
# 388/388 [==============================] - ETA: 0s - loss: 0.6327 - accuracy: 0.7867
# Epoch 3: val_accuracy improved from 0.76911 to 0.77418, saving model to C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 142s 364ms/step - loss: 0.6327 - accuracy: 0.7867 - val_loss: 0.7998 - val_accuracy: 0.7742 - lr: 0.0010
# Epoch 4/100
# 388/388 [==============================] - ETA: 0s - loss: 0.5766 - accuracy: 0.8027
# Epoch 4: val_accuracy improved from 0.77418 to 0.78393, saving model to C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 140s 360ms/step - loss: 0.5766 - accuracy: 0.8027 - val_loss: 0.7915 - val_accuracy: 0.7839 - lr: 0.0010
# Epoch 5/100
# 388/388 [==============================] - ETA: 0s - loss: 0.4653 - accuracy: 0.8340
# Epoch 5: val_accuracy improved from 0.78393 to 0.79056, saving model to C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 137s 353ms/step - loss: 0.4653 - accuracy: 0.8340 - val_loss: 0.7616 - val_accuracy: 0.7906 - lr: 0.0010
# Epoch 6/100
# 388/388 [==============================] - ETA: 0s - loss: 0.4371 - accuracy: 0.8470
# Epoch 6: val_accuracy improved from 0.79056 to 0.79836, saving model to C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 140s 360ms/step - loss: 0.4371 - accuracy: 0.8470 - val_loss: 0.7011 - val_accuracy: 0.7984 - lr: 0.0010
# Epoch 7/100
# 388/388 [==============================] - ETA: 0s - loss: 0.4288 - accuracy: 0.8501
# Epoch 7: val_accuracy did not improve from 0.79836
# 388/388 [==============================] - 131s 338ms/step - loss: 0.4288 - accuracy: 0.8501 - val_loss: 0.7869 - val_accuracy: 0.7894 - lr: 0.0010
# Epoch 8/100
# 388/388 [==============================] - ETA: 0s - loss: 0.4178 - accuracy: 0.8589
# Epoch 8: val_accuracy did not improve from 0.79836
# 388/388 [==============================] - 135s 347ms/step - loss: 0.4178 - accuracy: 0.8589 - val_loss: 0.8347 - val_accuracy: 0.7781 - lr: 0.0010
# Epoch 9/100
# 388/388 [==============================] - ETA: 0s - loss: 0.3663 - accuracy: 0.8696
# Epoch 9: val_accuracy did not improve from 0.79836
# 388/388 [==============================] - 134s 345ms/step - loss: 0.3663 - accuracy: 0.8696 - val_loss: 0.7631 - val_accuracy: 0.7952 - lr: 0.0010
# Epoch 10/100
# 388/388 [==============================] - ETA: 0s - loss: 0.3773 - accuracy: 0.8733
# Epoch 10: val_accuracy did not improve from 0.79836
# 388/388 [==============================] - 133s 343ms/step - loss: 0.3773 - accuracy: 0.8733 - val_loss: 0.8530 - val_accuracy: 0.7835 - lr: 0.0010
# Epoch 11/100
# 388/388 [==============================] - ETA: 0s - loss: 0.3662 - accuracy: 0.8772
# Epoch 11: val_accuracy did not improve from 0.79836
# 388/388 [==============================] - 132s 341ms/step - loss: 0.3662 - accuracy: 0.8772 - val_loss: 0.7936 - val_accuracy: 0.7902 - lr: 0.0010
# Epoch 12/100
# 388/388 [==============================] - ETA: 0s - loss: 0.2414 - accuracy: 0.9107
# Epoch 12: val_accuracy improved from 0.79836 to 0.81357, saving model to C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 138s 356ms/step - loss: 0.2414 - accuracy: 0.9107 - val_loss: 0.7122 - val_accuracy: 0.8136 - lr: 2.0000e-04
# Epoch 13/100
# 388/388 [==============================] - ETA: 0s - loss: 0.2298 - accuracy: 0.9151
# Epoch 13: val_accuracy improved from 0.81357 to 0.82020, saving model to C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 138s 354ms/step - loss: 0.2298 - accuracy: 0.9151 - val_loss: 0.7135 - val_accuracy: 0.8202 - lr: 2.0000e-04
# Epoch 14/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1977 - accuracy: 0.9249
# Epoch 14: val_accuracy did not improve from 0.82020
# 388/388 [==============================] - 134s 344ms/step - loss: 0.1977 - accuracy: 0.9249 - val_loss: 0.6890 - val_accuracy: 0.8179 - lr: 2.0000e-04
# Epoch 15/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1828 - accuracy: 0.9309
# Epoch 15: val_accuracy did not improve from 0.82020
# 388/388 [==============================] - 134s 346ms/step - loss: 0.1828 - accuracy: 0.9309 - val_loss: 0.6913 - val_accuracy: 0.8171 - lr: 2.0000e-04
# Epoch 16/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1719 - accuracy: 0.9349
# Epoch 16: val_accuracy did not improve from 0.82020
# 388/388 [==============================] - 135s 347ms/step - loss: 0.1719 - accuracy: 0.9349 - val_loss: 0.7353 - val_accuracy: 0.8183 - lr: 2.0000e-04
# Epoch 17/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9384
# Epoch 17: val_accuracy improved from 0.82020 to 0.82137, saving model to C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 140s 361ms/step - loss: 0.1606 - accuracy: 0.9384 - val_loss: 0.6832 - val_accuracy: 0.8214 - lr: 2.0000e-04
# Epoch 18/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9443
# Epoch 18: val_accuracy improved from 0.82137 to 0.82644, saving model to C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 140s 360ms/step - loss: 0.1525 - accuracy: 0.9443 - val_loss: 0.6802 - val_accuracy: 0.8264 - lr: 2.0000e-04
# Epoch 19/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9452
# Epoch 19: val_accuracy improved from 0.82644 to 0.82878, saving model to C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 148s 380ms/step - loss: 0.1434 - accuracy: 0.9452 - val_loss: 0.6682 - val_accuracy: 0.8288 - lr: 2.0000e-04
# Epoch 20/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1311 - accuracy: 0.9472
# Epoch 20: val_accuracy did not improve from 0.82878
# 388/388 [==============================] - 151s 389ms/step - loss: 0.1311 - accuracy: 0.9472 - val_loss: 0.6942 - val_accuracy: 0.8214 - lr: 2.0000e-04
# Epoch 21/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9483
# Epoch 21: val_accuracy did not improve from 0.82878
# 388/388 [==============================] - 156s 400ms/step - loss: 0.1356 - accuracy: 0.9483 - val_loss: 0.6847 - val_accuracy: 0.8241 - lr: 2.0000e-04
# Epoch 22/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9557
# Epoch 22: val_accuracy improved from 0.82878 to 0.83268, saving model to C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 148s 380ms/step - loss: 0.1192 - accuracy: 0.9557 - val_loss: 0.6842 - val_accuracy: 0.8327 - lr: 2.0000e-04
# Epoch 23/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1260 - accuracy: 0.9515
# Epoch 23: val_accuracy did not improve from 0.83268
# 388/388 [==============================] - 141s 362ms/step - loss: 0.1260 - accuracy: 0.9515 - val_loss: 0.6966 - val_accuracy: 0.8276 - lr: 2.0000e-04
# Epoch 24/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1231 - accuracy: 0.9541
# Epoch 24: val_accuracy did not improve from 0.83268
# 388/388 [==============================] - 144s 370ms/step - loss: 0.1231 - accuracy: 0.9541 - val_loss: 0.6820 - val_accuracy: 0.8319 - lr: 2.0000e-04
# Epoch 25/100
# 388/388 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9593
# Epoch 25: val_accuracy did not improve from 0.83268
# 388/388 [==============================] - 138s 356ms/step - loss: 0.1044 - accuracy: 0.9593 - val_loss: 0.6891 - val_accuracy: 0.8323 - lr: 4.0000e-05
# Epoch 26/100
# 388/388 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9626
# Epoch 26: val_accuracy improved from 0.83268 to 0.83346, saving model to C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 142s 367ms/step - loss: 0.0997 - accuracy: 0.9626 - val_loss: 0.6827 - val_accuracy: 0.8335 - lr: 4.0000e-05
# Epoch 27/100
# 388/388 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9661
# Epoch 27: val_accuracy improved from 0.83346 to 0.83541, saving model to C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5
# 388/388 [==============================] - 144s 371ms/step - loss: 0.0898 - accuracy: 0.9661 - val_loss: 0.6801 - val_accuracy: 0.8354 - lr: 4.0000e-05
# Epoch 28/100
# 388/388 [==============================] - ETA: 0s - loss: 0.0944 - accuracy: 0.9647
# Epoch 28: val_accuracy did not improve from 0.83541
# 388/388 [==============================] - 140s 359ms/step - loss: 0.0944 - accuracy: 0.9647 - val_loss: 0.6815 - val_accuracy: 0.8331 - lr: 4.0000e-05
# Epoch 29/100
# 388/388 [==============================] - ETA: 0s - loss: 0.0971 - accuracy: 0.9639
# Epoch 29: val_accuracy did not improve from 0.83541
# 388/388 [==============================] - 140s 360ms/step - loss: 0.0971 - accuracy: 0.9639 - val_loss: 0.6819 - val_accuracy: 0.8327 - lr: 4.0000e-05

# %%
custom_resnet_model.save(r'C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\custom_resnetv2_NAmodel.h5')

# %%
def plotTraining(hist, epochs, typeData):

    if typeData=="loss":
        plt.figure(1,figsize=(10,5))
        yc=hist.history['loss']
        xc=range(epochs)
        plt.ylabel('Loss', fontsize=24)
        plt.plot(xc,yc,'-r',label='Loss Training')
    if typeData=="accuracy":
        plt.figure(2,figsize=(10,5))
        yc=hist.history['accuracy']
        for i in range(0, len(yc)):
            yc[i]=100*yc[i]
        xc=range(epochs)
        plt.ylabel('Accuracy (%)', fontsize=24)
        plt.plot(xc,yc,'-r',label='Accuracy Training')
    if typeData=="val_loss":
        plt.figure(1,figsize=(10,5))
        yc=hist.history['val_loss']
        xc=range(epochs)
        plt.ylabel('Loss', fontsize=24)
        plt.plot(xc,yc,'-b',label='Loss Validate')
    if typeData=="val_accuracy":
        plt.figure(2,figsize=(10,5))
        yc=hist.history['val_accuracy']
        for i in range(0, len(yc)):
            yc[i]=100*yc[i]
        xc=range(epochs)
        plt.ylabel('Accuracy (%)', fontsize=24)
        plt.plot(xc,yc,'-b',label='Training Validate')


    plt.rc('xtick',labelsize=24)
    plt.rc('ytick',labelsize=24)
    plt.rc('legend', fontsize=18)
    plt.legend()
    plt.xlabel('Number of Epochs',fontsize=24)
    plt.grid(True)

# %%
num_epochs_done = len(custom_resnet_model_history.history['loss'])

plotTraining(custom_resnet_model_history,num_epochs_done,"loss")
plotTraining(custom_resnet_model_history,num_epochs_done,"accuracy")
plotTraining(custom_resnet_model_history,num_epochs_done,"val_loss")
plotTraining(custom_resnet_model_history,num_epochs_done,"val_accuracy")

# %%
from keras.applications.imagenet_utils import preprocess_input, decode_predictions
from tensorflow.keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array

# nombres de las clases
names = ['AGUJA COLINERA',
          'ALCA COMÚN',
          'AVEFRÍA EUROPEA',
          'AVIÓN ROQUERO',
          'AVOCETA COMÚN',
          'CHARRÁN PATINEGRO',
          'CHORLITO DORADO EUROPEO',
          'ESTORNINO PINTO',
          'FLAMENCO COMUN',
          'FOCHA COMUN',
          'GARCILLA VUEYERA OCCIDENTAL',
          'GAVIOTA PATIAMARILLA',
          'GAVIOTA PICOFINA',
          'GAVIOTA REIDORA',
          'GOLONDRINA COMUN',
          'GORRIÓN COMÚN',
          'GRAJILLA OCCIDENTAL',
          'JILGUERO EUROPEO',
          'MORITO COMÚN',
          'PALOMA TORCAZ',
          'PARDELA BALEAR',
          'PATO CUCHARÓN NORTEÑO',
          'SERÍN VERDECILLO',
          'VENCEJO COMÚN']

# cargar el 
modelt = load_model(r"C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5")

# ruta de la imagen
imaget_path = r'C:\Users\johns\Desktop\TFG\Dataset\test\SERÍN VERDECILLO\1365.jpg'

# cargar y redimensionar la imagen
imaget = load_img(imaget_path, target_size=(width_shape, height_shape))
imaget = img_to_array(imaget)
imaget = imaget.reshape((1,) + imaget.shape)

# preprocesar la imagen
xt = imaget / 255.0  # Normalizar la imagen

# hacer predicciones
preds = modelt.predict(xt)

# obtener la clase predicha
predicted_class = np.argmax(preds)
class_name = names[predicted_class]

print(class_name)

# mostrar la imagen
plt.imshow(cv2.cvtColor(imaget.reshape(width_shape, height_shape, 3).astype(np.uint8), cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[16], line 32
#       6 names = ['AGUJA COLINERA',
#       7           'ALCA COMÚN',
#       8           'AVEFRÍA EUROPEA',
#    (...)
#      28           'SERÍN VERDECILLO',
#      29           'VENCEJO COMÚN']
#      31 # cargar el
# ---> 32 modelt = load_model(r"C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\best_resnetv2_NAmodel.h5")
#      34 # ruta de la imagen
#      35 imaget_path = r'C:\Users\johns\Desktop\TFG\Dataset\test\SERÍN VERDECILLO\1365.jpg'
#
# File ~\anaconda3\envs\prueba\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\anaconda3\envs\prueba\lib\site-packages\keras\backend.py:1920, in RandomGenerator.random_uniform(self, shape, minval, maxval, dtype)
#    1917 if self._generator:
#    1918   return self._generator.uniform(
#    1919       shape=shape, minval=minval, maxval=maxval, dtype=dtype)
# -> 1920 return tf.random.uniform(
#    1921     shape=shape, minval=minval, maxval=maxval, dtype=dtype,
#    1922     seed=self.make_legacy_seed())
#
# ResourceExhaustedError: OOM when allocating tensor with shape[100352,1024] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:RandomUniform]

# %%
from sklearn.metrics import confusion_matrix, classification_report
from keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, f1_score, roc_curve, precision_score, recall_score, accuracy_score, roc_auc_score
from keras.preprocessing.image import ImageDataGenerator
from sklearn import metrics
from mlxtend.plotting import plot_confusion_matrix
# %matplotlib inline

# Definir el generador de datos de prueba
test_data_dir = r'C:\Users\johns\Desktop\TFG\Dataset\test'

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(height_shape, width_shape),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=False
)

# Load the model
custom_Model= load_model(r'C:\Users\johns\Desktop\TFG\MasCapas\RESNET152V2\custom_resnetv2_NAmodel.h5')

# Make predictions
predictions = custom_Model.predict_generator(generator=test_generator, steps=len(test_generator))
y_pred = np.argmax(predictions, axis=1)
y_real = test_generator.classes

# Map class names to class indices
class_indices = test_generator.class_indices
names = list(class_indices.keys())

# Generate confusion matrix
conf_matrix = confusion_matrix(y_real, y_pred)

# Plot confusion matrix
plt.figure(figsize=(15, 15))

plot_confusion_matrix(conf_mat=conf_matrix, figsize=(15, 15), class_names=names, show_normed=True)
plt.tight_layout()

# Print classification report
print(classification_report(y_real, y_pred, digits = 4))

# %%
print(y_real)

# %%
print(y_pred)
